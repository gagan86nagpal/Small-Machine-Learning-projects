# %%
# %matplotlib notebook
import tweepy
from textblob import TextBlob
import nltk
import numpy as np
import matplotlib.pyplot as plt

# %%
consumer_key  ='HNtZ46XCgZJQ2pZVzwzhnIave'
consumer_secret='xDJ5dHiozbsBbYNixEHIasKWpLoq5xpZjcjsRxxm2RDMdNPEEc'
access_token ='455680833-gnd1Kjd7m6YAZwEpKId6K0WSBLmijmvtJZJH5fC4'
access_token_secret ='JwQ5KhD52QcmtoUuH9BV81irUROwLHx4OtJKejlteYg3m'

# %%
auth =tweepy.OAuthHandler(consumer_key=consumer_key,consumer_secret=consumer_secret)
auth.set_access_token(access_token,access_token_secret)

# %%
api = tweepy.API(auth)

# %%
inp = input('Enter the buzz word: ')
polarity_list = []
public_tweet  = api.search(inp)
for tweets in public_tweet:
   # print(tweets.text)
    analysis = TextBlob(tweets.text)
    polarity_list.append(analysis.sentiment.polarity)
polarity_np = np.asarray(polarity_list)
print('Polarity of {}: {}'.format(inp,np.mean(polarity_np)))
fig,ax = plt.subplots()
plt.bar([i for i in range(0,len(polarity_list))] , polarity_list,label  = 'Histogram')
for x,y in enumerate(polarity_list):
    x=x-0.35
    if(y>=0):
        y=y+0.02
    else:
        y=y-0.08
    ax.text(x,y,'{:.1f}'.format(polarity_list[int(x+1)]),fontsize=8)
    
plt.ylim(-1,1);
# Out:
# Enter the buzz word: krishna
# Polarity of krishna: 0.045714285714285714
# <img src="data:image/png;base64,..." width="640">

# %%
# ?ax.text
